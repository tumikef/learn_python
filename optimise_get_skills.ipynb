# %% [markdown]
# <a href="https://colab.research.google.com/github/tumikef/learn_python/blob/master/optimise_get_skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def describe_skill(skill):
    return f"{skill['name']} ({skill['level']})"

skills = [
    {"name": "python", "level": "beginner"},
    {"name": "Java", "level": "beginner"},
    {"name": "sql", "level": "intermediate"},
]

names2 = [f"{skill['name']} ({skill['level']})" for skill in skills]
print(names2)

def get_request(Any):
  r = requests.get(f'https://api.github.com/users/{any}')
  return r.json()
# Out:
# ['python (beginner)', 'Java (beginner)', 'sql (intermediate)']
