# %% [markdown]
# <a href="https://colab.research.google.com/github/tumikef/learn_python/blob/master/read_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Writer
import csv
import os


skills = [
    {"name": "python", "level": "beginner"},
    {"name": "Java", "level": "beginner"},
    {"name": "sql", "level": "intermediate"},
]

fieldnames = ["name", "level"]
with open("skills.csv", "w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(skills)

print(os.path.exists("skills.csv"))
print(os.path.getsize("skills.csv"))
print(os.path.abspath("skills.csv"))

# %%
from typing_extensions import Reader
import csv
import os

with open("skills.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(row)

print(os.path.exists("skills.csv"))
print(os.path.getsize("skills.csv"))
print(os.path.abspath("skills.csv"))
# Out:
# {'name': 'python', 'level': 'beginner'}
# {'name': 'Java', 'level': 'beginner'}
# {'name': 'sql', 'level': 'intermediate'}
# True
# 62
# /content/skills.csv
